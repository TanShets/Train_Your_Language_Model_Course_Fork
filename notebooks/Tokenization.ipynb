# %%
import sys
sys.path.append('..')

# %%
data = ''
with open('../output/data.txt', 'r', encoding='utf-8') as fp:
    data = '\n'.join(fp.readlines())

# %%
from minbpe.gpt4 import GPT4Tokenizer

tokenizer = GPT4Tokenizer()
tokenizer.train(data, vocab_size=2048)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from minbpe.gpt4 import GPT4Tokenizer
#       3 tokenizer = GPT4Tokenizer()
#       4 tokenizer.train(data, vocab_size=2048)
#
# File c:\Users\tanis\Documents\Tanish\programming\GPT\Train_Your_Language_Model_Course_Fork\notebooks\..\minbpe\__init__.py:4
#       2 from .basic import BasicTokenizer
#       3 from .regex import RegexTokenizer
# ----> 4 from .gpt4 import GPT4Tokenizer
#
# File c:\Users\tanis\Documents\Tanish\programming\GPT\Train_Your_Language_Model_Course_Fork\notebooks\..\minbpe\gpt4.py:7
#       1 """
#       2 Implements the GPT-4 Tokenizer as a light wrapper around the RegexTokenizer.
#       3 Note that this is a pretrained tokenizer. By default and inside init(), it
#       4 loads the pretrained tokenizer from the `cl100k_base` tokenizer of tiktoken.
#       5 """
# ----> 7 import tiktoken
#       8 from .regex import RegexTokenizer
#      11 def bpe(mergeable_ranks, token, max_rank):
#      12     # helper function used in get_gpt4_merges() to reconstruct the merge forest
#
# ModuleNotFoundError: No module named 'tiktoken'
